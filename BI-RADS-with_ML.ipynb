# %%
#reading the data
import pandas as pd
df_rad=pd.read_csv('/Users/deepureddy/Desktop/REDI/radiology_reports_birads_score_STUDENTS_PRO.csv')
df_rad
# Out:
#           Id                                          Report_MG  \
# 0          0                                                NaN
# 1          1  Medische gegevens:\ncontrole mammografie afwij...
# 2          2  Klinische gegevens:\nfollowup kadermammacarcin...
# 3          3  Medische gegevens:\nControle mammografie.\n\nX...
# 4          4  Medische gegevens:\nMammacarcinoom rechts. Fol...
# ...      ...                                                ...
# 54397  54397  Klinische gegevens:\n41-jarige vrouw uit Henge...
# 54398  54398  Klinische gegevens:\n46-jarige vrouw uit Borne...
# 54399  54399                                                NaN
# 54400  54400  Klinische gegevens:\n35-jarige vrouw uit Almel...
# 54401  54401  Klinische gegevens:\n40-jarige vrouw uit Bente...
#
#                                                Report_US  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 54397                                                NaN
# 54398  Klinische gegevens:\n46-jarige vrouw uit Borne...
# 54399  Addendum:\nDe punctie heeft plaatsgevonden op ...
# 54400  Klinische gegevens:\n35-jarige vrouw uit Almel...
# 54401  Klinische gegevens:\n40-jarige vrouw uit Bente...
#
#                                               Report_MRI BIRADS
# 0      Medische gegevens:\nFU na mammaca li, re excis...      0
# 1                                                    NaN     II
# 2                                                    NaN     II
# 3                                                    NaN     II
# 4                                                    NaN      I
# ...                                                  ...    ...
# 54397                                                NaN    een
# 54398                                                NaN   twee
# 54399                                                NaN    NaN
# 54400                                                NaN   twee
# 54401                                                NaN   twee
#
# [54402 rows x 5 columns]

# %%
import re

# %%
#convert into lower case and then get the Uniformity in the BIRADS score
df_rad = df_rad.apply(lambda x: x.astype(str).str.lower())

# %%
df_rad["BIRADS"] = df_rad["BIRADS"].replace("i",1)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("ii",2)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("iii",3)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("iv",4)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("v",5)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("vi",6)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("vii",7)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("viii",8)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("ix",9)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("x",10)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("een",1)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("twee",2)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("drie",3)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("vier",4)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("vijf",5)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("zes",6)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("zeven",7)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("acht",8)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("negen",9)
df_rad["BIRADS"] = df_rad["BIRADS"].replace("tien",10)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('iva', 4)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('ivb', 4)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('ivc', 4)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('ivd', 4)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('4a', 4)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('4b', 4)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('4c', 4)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('4d', 4)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('0', 0)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('1', 1)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('2', 2)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('3', 3)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('4', 4)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('5', 5)
df_rad['BIRADS'] = df_rad['BIRADS'].replace('6', 6)
df_rad
# Out:
#           Id                                          Report_MG  \
# 0          0                                                nan
# 1          1  medische gegevens:\ncontrole mammografie afwij...
# 2          2  klinische gegevens:\nfollowup kadermammacarcin...
# 3          3  medische gegevens:\ncontrole mammografie.\n\nx...
# 4          4  medische gegevens:\nmammacarcinoom rechts. fol...
# ...      ...                                                ...
# 54397  54397  klinische gegevens:\n41-jarige vrouw uit henge...
# 54398  54398  klinische gegevens:\n46-jarige vrouw uit borne...
# 54399  54399                                                nan
# 54400  54400  klinische gegevens:\n35-jarige vrouw uit almel...
# 54401  54401  klinische gegevens:\n40-jarige vrouw uit bente...
#
#                                                Report_US  \
# 0                                                    nan
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 54397                                                nan
# 54398  klinische gegevens:\n46-jarige vrouw uit borne...
# 54399  addendum:\nde punctie heeft plaatsgevonden op ...
# 54400  klinische gegevens:\n35-jarige vrouw uit almel...
# 54401  klinische gegevens:\n40-jarige vrouw uit bente...
#
#                                               Report_MRI BIRADS
# 0      medische gegevens:\nfu na mammaca li, re excis...      0
# 1                                                    nan      2
# 2                                                    nan      2
# 3                                                    nan      2
# 4                                                    nan      1
# ...                                                  ...    ...
# 54397                                                nan      1
# 54398                                                nan      2
# 54399                                                nan    nan
# 54400                                                nan      2
# 54401                                                nan      2
#
# [54402 rows x 5 columns]

# %%
df_rad_1 = df_rad
df_rad_1
# Out:
#           Id                                          Report_MG  \
# 0          0                                                nan
# 1          1  medische gegevens:\ncontrole mammografie afwij...
# 2          2  klinische gegevens:\nfollowup kadermammacarcin...
# 3          3  medische gegevens:\ncontrole mammografie.\n\nx...
# 4          4  medische gegevens:\nmammacarcinoom rechts. fol...
# ...      ...                                                ...
# 54397  54397  klinische gegevens:\n41-jarige vrouw uit henge...
# 54398  54398  klinische gegevens:\n46-jarige vrouw uit borne...
# 54399  54399                                                nan
# 54400  54400  klinische gegevens:\n35-jarige vrouw uit almel...
# 54401  54401  klinische gegevens:\n40-jarige vrouw uit bente...
#
#                                                Report_US  \
# 0                                                    nan
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 54397                                                nan
# 54398  klinische gegevens:\n46-jarige vrouw uit borne...
# 54399  addendum:\nde punctie heeft plaatsgevonden op ...
# 54400  klinische gegevens:\n35-jarige vrouw uit almel...
# 54401  klinische gegevens:\n40-jarige vrouw uit bente...
#
#                                               Report_MRI BIRADS
# 0      medische gegevens:\nfu na mammaca li, re excis...      0
# 1                                                    nan      2
# 2                                                    nan      2
# 3                                                    nan      2
# 4                                                    nan      1
# ...                                                  ...    ...
# 54397                                                nan      1
# 54398                                                nan      2
# 54399                                                nan    nan
# 54400                                                nan      2
# 54401                                                nan      2
#
# [54402 rows x 5 columns]

# %%
#remove all the special chars
import pandas as pd
import numpy as np
spec_chars = ["!",'"',"#","%","&","'","(",")",
              "*","+",",","-",".","/",":",";","<",
              "=",">","?","@","[","\\","]","^","_",
              "`","{","|","}","~","–","\n",'ii','iii',"\d","Verslag:", "medische", "gegevens"]
for char in spec_chars:
    df_rad_1['Report_MG'] = df_rad_1['Report_MG'].str.replace(char, ' ')
    df_rad_1['Report_US'] = df_rad_1['Report_US'].str.replace(char, ' ')
    df_rad_1['Report_MRI'] = df_rad_1['Report_MRI'].str.replace(char, ' ')

# %%
df_rad_1['Report_MG'] = df_rad_1['Report_MG'].str.split("conclusie:",expand=True)[0]
df_rad_1['Report_MG'] = df_rad_1['Report_MG'].str.split("conclusie",expand=True)[0]

# %%
df_ploted = df_rad_1['BIRADS'].value_counts()
df_ploted.plot.bar(x="test", y="gest", rot=100, title="BIRADS Data distrubtion")
# Out:
# <AxesSubplot:title={'center':'BIRADS Data distrubtion'}>

# %%
df_rad_1.drop(df_rad_1.index[df_rad_1['BIRADS'] == 'nan'], inplace = True)
df_rad_1.drop(df_rad_1.index[df_rad_1['BIRADS'] == '7'], inplace = True)
df_rad_1.drop(df_rad_1.index[df_rad_1['BIRADS'] == '8'], inplace = True)
df_rad_1.drop(df_rad_1.index[df_rad_1['BIRADS'] == '9'], inplace = True)

# %%
#class imbalace check
df_ploted = df_rad_1['BIRADS'].value_counts()
df_ploted.plot.bar(x="test", y="gest", rot=100, title="BIRADS Data distrubtion")
# Out:
# <AxesSubplot:title={'center':'BIRADS Data distrubtion'}>

# %%
df_rad_1
# Out:
#           Id                                          Report_MG  \
# 0          0                                                nan
# 1          1       controle mammografie afwijkingen    versl...
# 2          2  klinische    followup kadermammacarcinoom rech...
# 3          3       controle mammografie   x mammografie rech...
# 4          4       mammacarcinoom rechts  follow up   versla...
# ...      ...                                                ...
# 54395  54395  klinische       jarige vrouw uit hengelo komt ...
# 54397  54397  klinische       jarige vrouw uit hengelo voelt...
# 54398  54398  klinische       jarige vrouw uit borne voelt s...
# 54400  54400  klinische       jarige vrouw uit almelo heeft ...
# 54401  54401  klinische       jarige vrouw uit bentelo voelt...
#
#                                                Report_US  \
# 0                                                    nan
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 54395  klinische       jarige vrouw uit hengelo komt ...
# 54397                                                nan
# 54398  klinische       jarige vrouw uit borne voelt s...
# 54400  klinische       jarige vrouw uit almelo heeft ...
# 54401  klinische       jarige vrouw uit bentelo voelt...
#
#                                               Report_MRI BIRADS
# 0           fu na mammaca li  re excisiebiopt gehad  ...      0
# 1                                                    nan      2
# 2                                                    nan      2
# 3                                                    nan      2
# 4                                                    nan      1
# ...                                                  ...    ...
# 54395                                                nan      4
# 54397                                                nan      1
# 54398                                                nan      2
# 54400                                                nan      2
# 54401                                                nan      2
#
# [42502 rows x 5 columns]

# %%
import nltk
from nltk.corpus import stopwords
print(stopwords.words('dutch'))
# Out:
# ['de', 'en', 'van', 'ik', 'te', 'dat', 'die', 'in', 'een', 'hij', 'het', 'niet', 'zijn', 'is', 'was', 'op', 'aan', 'met', 'als', 'voor', 'had', 'er', 'maar', 'om', 'hem', 'dan', 'zou', 'of', 'wat', 'mijn', 'men', 'dit', 'zo', 'door', 'over', 'ze', 'zich', 'bij', 'ook', 'tot', 'je', 'mij', 'uit', 'der', 'daar', 'haar', 'naar', 'heb', 'hoe', 'heeft', 'hebben', 'deze', 'u', 'want', 'nog', 'zal', 'me', 'zij', 'nu', 'ge', 'geen', 'omdat', 'iets', 'worden', 'toch', 'al', 'waren', 'veel', 'meer', 'doen', 'toen', 'moet', 'ben', 'zonder', 'kan', 'hun', 'dus', 'alles', 'onder', 'ja', 'eens', 'hier', 'wie', 'werd', 'altijd', 'doch', 'wordt', 'wezen', 'kunnen', 'ons', 'zelf', 'tegen', 'na', 'reeds', 'wil', 'kon', 'niets', 'uw', 'iemand', 'geweest', 'andere']

# %%
df_training = df_rad_1[['Id','Report_MG','BIRADS']]

# %%
df_training.drop(df_training.index[df_training['Report_MG'] == 'nan'], inplace = True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_training
# Out:
#           Id                                          Report_MG BIRADS
# 1          1       controle mammografie afwijkingen    versl...      2
# 2          2  klinische    followup kadermammacarcinoom rech...      2
# 3          3       controle mammografie   x mammografie rech...      2
# 4          4       mammacarcinoom rechts  follow up   versla...      1
# 6          6  indicatie  fu in het kader van een belaste fa ...      1
# ...      ...                                                ...    ...
# 54395  54395  klinische       jarige vrouw uit hengelo komt ...      4
# 54397  54397  klinische       jarige vrouw uit hengelo voelt...      1
# 54398  54398  klinische       jarige vrouw uit borne voelt s...      2
# 54400  54400  klinische       jarige vrouw uit almelo heeft ...      2
# 54401  54401  klinische       jarige vrouw uit bentelo voelt...      2
#
# [35030 rows x 3 columns]

# %%
new_ploted = df_training['BIRADS'].value_counts()
new_ploted.plot.bar(title="BIRADS Data distrubtion")
# Out:
# <AxesSubplot:title={'center':'BIRADS Data distrubtion'}>

# %%
import nltk.corpus
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('dutch')
stop.remove('geen')
df_training['cleaned_text'] = df_training['Report_MG'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
df_training.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/deepureddy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <ipython-input-17-598a4a7d9c6f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_training['cleaned_text'] = df_training['Report_MG'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
#   Id                                          Report_MG BIRADS  \
# 1  1       controle mammografie afwijkingen    versl...      2
# 2  2  klinische    followup kadermammacarcinoom rech...      2
# 3  3       controle mammografie   x mammografie rech...      2
# 4  4       mammacarcinoom rechts  follow up   versla...      1
# 6  6  indicatie  fu in het kader van een belaste fa ...      1
#
#                                         cleaned_text
# 1  controle mammografie afwijkingen verslag verge...
# 2  klinische followup kadermammacarcinoom rechts ...
# 3  controle mammografie x mammografie rechts verg...
# 4  mammacarcinoom rechts follow up verslag ter ve...
# 6  indicatie fu kader belaste fa verslag t o v ap...

# %%
df_training.cleaned_text.iloc[2]
# Out:
# 'controle mammografie x mammografie rechts vergelijkend onderzoek onveranderd beeld beeld scleroserende fibroadenosis suggestieve schaduw centraal laterale gedeelte rechtermamma craniocaudale opname detailopname reproduceerbaar beeld passend summatie geen aanwijzingen maligniteit axillair geen vergrote lymfeklieren'

# %%
import nltk 
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
df_training['tokenized_text'] = df_training['cleaned_text'].apply(lambda x: word_tokenize(x))
df_training.head()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/deepureddy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <ipython-input-19-f071ec629e63>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_training['tokenized_text'] = df_training['cleaned_text'].apply(lambda x: word_tokenize(x))
#   Id                                          Report_MG BIRADS  \
# 1  1       controle mammografie afwijkingen    versl...      2
# 2  2  klinische    followup kadermammacarcinoom rech...      2
# 3  3       controle mammografie   x mammografie rech...      2
# 4  4       mammacarcinoom rechts  follow up   versla...      1
# 6  6  indicatie  fu in het kader van een belaste fa ...      1
#
#                                         cleaned_text  \
# 1  controle mammografie afwijkingen verslag verge...
# 2  klinische followup kadermammacarcinoom rechts ...
# 3  controle mammografie x mammografie rechts verg...
# 4  mammacarcinoom rechts follow up verslag ter ve...
# 6  indicatie fu kader belaste fa verslag t o v ap...
#
#                                       tokenized_text
# 1  [controle, mammografie, afwijkingen, verslag, ...
# 2  [klinische, followup, kadermammacarcinoom, rec...
# 3  [controle, mammografie, x, mammografie, rechts...
# 4  [mammacarcinoom, rechts, follow, up, verslag, ...
# 6  [indicatie, fu, kader, belaste, fa, verslag, t...

# %%
from nltk.stem import PorterStemmer
def word_stemmer(text):
    stem_text = [PorterStemmer().stem(i) for i in text]
    return stem_text
df_training['text_tokens_stem'] = df_training['tokenized_text'].apply(lambda x: word_stemmer(x))
df_training.head()
# Out:
# <ipython-input-20-6f54dbc9277e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_training['text_tokens_stem'] = df_training['tokenized_text'].apply(lambda x: word_stemmer(x))
#   Id                                          Report_MG BIRADS  \
# 1  1       controle mammografie afwijkingen    versl...      2
# 2  2  klinische    followup kadermammacarcinoom rech...      2
# 3  3       controle mammografie   x mammografie rech...      2
# 4  4       mammacarcinoom rechts  follow up   versla...      1
# 6  6  indicatie  fu in het kader van een belaste fa ...      1
#
#                                         cleaned_text  \
# 1  controle mammografie afwijkingen verslag verge...
# 2  klinische followup kadermammacarcinoom rechts ...
# 3  controle mammografie x mammografie rechts verg...
# 4  mammacarcinoom rechts follow up verslag ter ve...
# 6  indicatie fu kader belaste fa verslag t o v ap...
#
#                                       tokenized_text  \
# 1  [controle, mammografie, afwijkingen, verslag, ...
# 2  [klinische, followup, kadermammacarcinoom, rec...
# 3  [controle, mammografie, x, mammografie, rechts...
# 4  [mammacarcinoom, rechts, follow, up, verslag, ...
# 6  [indicatie, fu, kader, belaste, fa, verslag, t...
#
#                                     text_tokens_stem
# 1  [control, mammografi, afwijkingen, verslag, ve...
# 2  [klinisch, followup, kadermammacarcinoom, rech...
# 3  [control, mammografi, x, mammografi, recht, ve...
# 4  [mammacarcinoom, recht, follow, up, verslag, t...
# 6  [indicati, fu, kader, belast, fa, verslag, t, ...

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
def word_lemmatizer(text):
    lem_text = [WordNetLemmatizer().lemmatize(i) for i in text]
    return lem_text
df_training['text_tokens_lemma'] = df_training['tokenized_text'].apply(lambda x: word_lemmatizer(x))
df_training.head()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/deepureddy/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# <ipython-input-21-c4cfd2a83da3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_training['text_tokens_lemma'] = df_training['tokenized_text'].apply(lambda x: word_lemmatizer(x))
#   Id                                          Report_MG BIRADS  \
# 1  1       controle mammografie afwijkingen    versl...      2
# 2  2  klinische    followup kadermammacarcinoom rech...      2
# 3  3       controle mammografie   x mammografie rech...      2
# 4  4       mammacarcinoom rechts  follow up   versla...      1
# 6  6  indicatie  fu in het kader van een belaste fa ...      1
#
#                                         cleaned_text  \
# 1  controle mammografie afwijkingen verslag verge...
# 2  klinische followup kadermammacarcinoom rechts ...
# 3  controle mammografie x mammografie rechts verg...
# 4  mammacarcinoom rechts follow up verslag ter ve...
# 6  indicatie fu kader belaste fa verslag t o v ap...
#
#                                       tokenized_text  \
# 1  [controle, mammografie, afwijkingen, verslag, ...
# 2  [klinische, followup, kadermammacarcinoom, rec...
# 3  [controle, mammografie, x, mammografie, rechts...
# 4  [mammacarcinoom, rechts, follow, up, verslag, ...
# 6  [indicatie, fu, kader, belaste, fa, verslag, t...
#
#                                     text_tokens_stem  \
# 1  [control, mammografi, afwijkingen, verslag, ve...
# 2  [klinisch, followup, kadermammacarcinoom, rech...
# 3  [control, mammografi, x, mammografi, recht, ve...
# 4  [mammacarcinoom, recht, follow, up, verslag, t...
# 6  [indicati, fu, kader, belast, fa, verslag, t, ...
#
#                                    text_tokens_lemma
# 1  [controle, mammografie, afwijkingen, verslag, ...
# 2  [klinische, followup, kadermammacarcinoom, rec...
# 3  [controle, mammografie, x, mammografie, rechts...
# 4  [mammacarcinoom, rechts, follow, up, verslag, ...
# 6  [indicatie, fu, kader, belaste, fa, verslag, t...

# %%
df_training.head(50)
# Out:
#     Id                                          Report_MG BIRADS  \
# 1    1       controle mammografie afwijkingen    versl...      2
# 2    2  klinische    followup kadermammacarcinoom rech...      2
# 3    3       controle mammografie   x mammografie rech...      2
# 4    4       mammacarcinoom rechts  follow up   versla...      1
# 6    6  indicatie  fu in het kader van een belaste fa ...      1
# 7    7  indicatie  controle mammografie  bij mammacarc...      1
# 8    8  indicatie  status na mso links   verslag  t o ...      1
# 17  17       mammacarcinoom links in       controle   ...      2
# 18  18  indicatie  belaste familieanamnese   verslag  ...      1
# 19  19  indicatie  tatus na fors mammaabces links  vra...      1
# 20  20       st na ablatio rechts ivm mammacarcinoom p...      1
# 21  21       follow up na ablatio rechts in        mam...      1
# 28  28       controle na ablatio links   verslag  mamm...      1
# 29  29       had geabcedeerde cyste l mamma  nu nog mg...      2
# 30  30  indicatie  follow up  familiaire belasting mam...      1
# 31  31       vervolgen  familiaire belasting  mastopat...      2
# 33  33  indicatie  in juli      cyste rechts  advies v...      2
# 36  36       jaarlijkse screening in verband met famil...      2
# 37  37       vervolgen  status na mammacarcinoom recht...      2
# 38  38       controle na sparende therapie rechts   ve...      2
# 39  39       status na sparende therapie rechts  vervo...      2
# 40  40       mca  verslag  mammografie rechts  standaa...      2
# 41  41       genetisch advies ter controle  bekend met...      2
# 42  42       belaste familie anamnese vor mammacarcino...      1
# 43  43  klinische    follow up  status na mamma ca   l...      2
# 44  44  klinische    follow up  status na mamma ca   l...      2
# 45  45       status na dcis re waarvoor ablatio  versl...      1
# 46  46       follow up  status na mammaca rechts  waar...      2
# 47  47       follow up  status na mammaca rechts    ve...      2
# 49  49       controle in verband met radiotherapie voo...      1
# 51  51       jaarlijkse mammografie   x mammografie be...      2
# 52  52       st na grm re  aanw maligniteit li mamma  ...      1
# 54  54  indicatie  fu  patiente dement  verslag  t o v...      2
# 56  56  indicatie  jaarlijkse controle   verslag  er b...      1
# 57  57       juli      microcalc met atypische ductaal...      2
# 58  58       familiair belast  ene jaar svob  andere j...      1
# 60  60       follow up bij status na mammasparende the...      2
# 63  63  klinische    belaste familieanamnese  mammogra...      1
# 64  64       vervolgen  status na sparende therapie re...      2
# 66  66       tien jaar na grm links   verslag  ter ver...      2
# 67  67       status na mst links in        verslag  te...      2
# 68  68       status na mammacarcinoom rechts waarvoor ...      2
# 69  69       status na mst links follow up na  ½ jaar ...      2
# 70  70  klinische    routineonderzoek  status na verwi...      1
# 71  71  indicatie  follow up ivm apocriene metaplasie ...      2
# 72  72       jaarlijkse controle   x mammografie beide...      2
# 73  73            mammacarcinoom links waarvoor lumpec...      2
# 74  74       controle mammografie bij doorgemaakt mamm...      2
# 75  75            mammacarcinoom rechts   verslag  mam...      2
# 76  76       patient heeft geen aanvraagbriefje  statu...      2
#
#                                          cleaned_text  \
# 1   controle mammografie afwijkingen verslag verge...
# 2   klinische followup kadermammacarcinoom rechts ...
# 3   controle mammografie x mammografie rechts verg...
# 4   mammacarcinoom rechts follow up verslag ter ve...
# 6   indicatie fu kader belaste fa verslag t o v ap...
# 7   indicatie controle mammografie mammacarcinoom ...
# 8   indicatie status mso links verslag t o v janua...
# 17  mammacarcinoom links controle verslag mammogra...
# 18  indicatie belaste familieanamnese verslag t o ...
# 19  indicatie tatus fors mammaabces links vraag te...
# 20  st ablatio rechts ivm mammacarcinoom pathologi...
# 21  follow up ablatio rechts mammografie links ver...
# 28  controle ablatio links verslag mammografie rec...
# 29  geabcedeerde cyste l mamma mgr ter uitsluiting...
# 30  indicatie follow up familiaire belasting mamma...
# 31  vervolgen familiaire belasting mastopathie aan...
# 33  indicatie juli cyste rechts advies via hertz c...
# 36  jaarlijkse screening verband familiaire belast...
# 37  vervolgen status mammacarcinoom rechts waarvoo...
# 38  controle sparende therapie rechts verslag mamm...
# 39  status sparende therapie rechts vervolgen vers...
# 40  mca verslag mammografie rechts standaardprotoc...
# 41  genetisch advies ter controle bekend cysten af...
# 42  belaste familie anamnese vor mammacarcinoom st...
# 43  klinische follow up status mamma ca links abla...
# 44  klinische follow up status mamma ca links mst ...
# 45  status dcis re waarvoor ablatio verslag mammog...
# 46  follow up status mammaca rechts waarvoor mst v...
# 47  follow up status mammaca rechts verslag mammog...
# 49  controle verband radiotherapie morbus hodgkin ...
# 51  jaarlijkse mammografie x mammografie beiderzij...
# 52  st grm re aanw maligniteit li mamma verslag ma...
# 54  indicatie fu patiente dement verslag t o v svo...
# 56  indicatie jaarlijkse controle verslag blijkt b...
# 57  juli microcalc atypische ductaal hyperplasie a...
# 58  familiair belast ene jaar svob jaar controle v...
# 60  follow up status mammasparende therapie rechts...
# 63  klinische belaste familieanamnese mammografie ...
# 64  vervolgen status sparende therapie rechts vers...
# 66  tien jaar grm links verslag ter vergelijking v...
# 67  status mst links verslag ter vergelijking mamm...
# 68  status mammacarcinoom rechts waarvoor mst vers...
# 69  status mst links follow up ½ jaar verslag ter ...
# 70  klinische routineonderzoek status verwijdering...
# 71  indicatie follow up ivm apocriene metaplasie c...
# 72  jaarlijkse controle x mammografie beiderzijds ...
# 73  mammacarcinoom links waarvoor lumpectomie okse...
# 74  controle mammografie doorgemaakt mammaca x mam...
# 75  mammacarcinoom rechts verslag mammografie volg...
# 76  patient geen aanvraagbriefje status mamma ampu...
#
#                                        tokenized_text  \
# 1   [controle, mammografie, afwijkingen, verslag, ...
# 2   [klinische, followup, kadermammacarcinoom, rec...
# 3   [controle, mammografie, x, mammografie, rechts...
# 4   [mammacarcinoom, rechts, follow, up, verslag, ...
# 6   [indicatie, fu, kader, belaste, fa, verslag, t...
# 7   [indicatie, controle, mammografie, mammacarcin...
# 8   [indicatie, status, mso, links, verslag, t, o,...
# 17  [mammacarcinoom, links, controle, verslag, mam...
# 18  [indicatie, belaste, familieanamnese, verslag,...
# 19  [indicatie, tatus, fors, mammaabces, links, vr...
# 20  [st, ablatio, rechts, ivm, mammacarcinoom, pat...
# 21  [follow, up, ablatio, rechts, mammografie, lin...
# 28  [controle, ablatio, links, verslag, mammografi...
# 29  [geabcedeerde, cyste, l, mamma, mgr, ter, uits...
# 30  [indicatie, follow, up, familiaire, belasting,...
# 31  [vervolgen, familiaire, belasting, mastopathie...
# 33  [indicatie, juli, cyste, rechts, advies, via, ...
# 36  [jaarlijkse, screening, verband, familiaire, b...
# 37  [vervolgen, status, mammacarcinoom, rechts, wa...
# 38  [controle, sparende, therapie, rechts, verslag...
# 39  [status, sparende, therapie, rechts, vervolgen...
# 40  [mca, verslag, mammografie, rechts, standaardp...
# 41  [genetisch, advies, ter, controle, bekend, cys...
# 42  [belaste, familie, anamnese, vor, mammacarcino...
# 43  [klinische, follow, up, status, mamma, ca, lin...
# 44  [klinische, follow, up, status, mamma, ca, lin...
# 45  [status, dcis, re, waarvoor, ablatio, verslag,...
# 46  [follow, up, status, mammaca, rechts, waarvoor...
# 47  [follow, up, status, mammaca, rechts, verslag,...
# 49  [controle, verband, radiotherapie, morbus, hod...
# 51  [jaarlijkse, mammografie, x, mammografie, beid...
# 52  [st, grm, re, aanw, maligniteit, li, mamma, ve...
# 54  [indicatie, fu, patiente, dement, verslag, t, ...
# 56  [indicatie, jaarlijkse, controle, verslag, bli...
# 57  [juli, microcalc, atypische, ductaal, hyperpla...
# 58  [familiair, belast, ene, jaar, svob, jaar, con...
# 60  [follow, up, status, mammasparende, therapie, ...
# 63  [klinische, belaste, familieanamnese, mammogra...
# 64  [vervolgen, status, sparende, therapie, rechts...
# 66  [tien, jaar, grm, links, verslag, ter, vergeli...
# 67  [status, mst, links, verslag, ter, vergelijkin...
# 68  [status, mammacarcinoom, rechts, waarvoor, mst...
# 69  [status, mst, links, follow, up, ½, jaar, vers...
# 70  [klinische, routineonderzoek, status, verwijde...
# 71  [indicatie, follow, up, ivm, apocriene, metapl...
# 72  [jaarlijkse, controle, x, mammografie, beiderz...
# 73  [mammacarcinoom, links, waarvoor, lumpectomie,...
# 74  [controle, mammografie, doorgemaakt, mammaca, ...
# 75  [mammacarcinoom, rechts, verslag, mammografie,...
# 76  [patient, geen, aanvraagbriefje, status, mamma...
#
#                                      text_tokens_stem  \
# 1   [control, mammografi, afwijkingen, verslag, ve...
# 2   [klinisch, followup, kadermammacarcinoom, rech...
# 3   [control, mammografi, x, mammografi, recht, ve...
# 4   [mammacarcinoom, recht, follow, up, verslag, t...
# 6   [indicati, fu, kader, belast, fa, verslag, t, ...
# 7   [indicati, control, mammografi, mammacarcinoom...
# 8   [indicati, statu, mso, link, verslag, t, o, v,...
# 17  [mammacarcinoom, link, control, verslag, mammo...
# 18  [indicati, belast, familieanamnes, verslag, t,...
# 19  [indicati, tatu, for, mammaabc, link, vraag, t...
# 20  [st, ablatio, recht, ivm, mammacarcinoom, path...
# 21  [follow, up, ablatio, recht, mammografi, link,...
# 28  [control, ablatio, link, verslag, mammografi, ...
# 29  [geabcedeerd, cyst, l, mamma, mgr, ter, uitslu...
# 30  [indicati, follow, up, familiair, belast, mamm...
# 31  [vervolgen, familiair, belast, mastopathi, aan...
# 33  [indicati, juli, cyst, recht, advi, via, hertz...
# 36  [jaarlijks, screen, verband, familiair, belast...
# 37  [vervolgen, statu, mammacarcinoom, recht, waar...
# 38  [control, sparend, therapi, recht, verslag, ma...
# 39  [statu, sparend, therapi, recht, vervolgen, ve...
# 40  [mca, verslag, mammografi, recht, standaardpro...
# 41  [genetisch, advi, ter, control, bekend, cysten...
# 42  [belast, famili, anamnes, vor, mammacarcinoom,...
# 43  [klinisch, follow, up, statu, mamma, ca, link,...
# 44  [klinisch, follow, up, statu, mamma, ca, link,...
# 45  [statu, dci, re, waarvoor, ablatio, verslag, m...
# 46  [follow, up, statu, mammaca, recht, waarvoor, ...
# 47  [follow, up, statu, mammaca, recht, verslag, m...
# 49  [control, verband, radiotherapi, morbu, hodgki...
# 51  [jaarlijks, mammografi, x, mammografi, beiderz...
# 52  [st, grm, re, aanw, maligniteit, li, mamma, ve...
# 54  [indicati, fu, patient, dement, verslag, t, o,...
# 56  [indicati, jaarlijks, control, verslag, blijkt...
# 57  [juli, microcalc, atypisch, ductaal, hyperplas...
# 58  [familiair, belast, ene, jaar, svob, jaar, con...
# 60  [follow, up, statu, mammasparend, therapi, rec...
# 63  [klinisch, belast, familieanamnes, mammografi,...
# 64  [vervolgen, statu, sparend, therapi, recht, ve...
# 66  [tien, jaar, grm, link, verslag, ter, vergelij...
# 67  [statu, mst, link, verslag, ter, vergelijk, ma...
# 68  [statu, mammacarcinoom, recht, waarvoor, mst, ...
# 69  [statu, mst, link, follow, up, ½, jaar, versla...
# 70  [klinisch, routineonderzoek, statu, verwijd, m...
# 71  [indicati, follow, up, ivm, apocrien, metaplas...
# 72  [jaarlijks, control, x, mammografi, beiderzijd...
# 73  [mammacarcinoom, link, waarvoor, lumpectomi, o...
# 74  [control, mammografi, doorgemaakt, mammaca, x,...
# 75  [mammacarcinoom, recht, verslag, mammografi, v...
# 76  [patient, geen, aanvraagbriefj, statu, mamma, ...
#
#                                     text_tokens_lemma
# 1   [controle, mammografie, afwijkingen, verslag, ...
# 2   [klinische, followup, kadermammacarcinoom, rec...
# 3   [controle, mammografie, x, mammografie, rechts...
# 4   [mammacarcinoom, rechts, follow, up, verslag, ...
# 6   [indicatie, fu, kader, belaste, fa, verslag, t...
# 7   [indicatie, controle, mammografie, mammacarcin...
# 8   [indicatie, status, mso, link, verslag, t, o, ...
# 17  [mammacarcinoom, link, controle, verslag, mamm...
# 18  [indicatie, belaste, familieanamnese, verslag,...
# 19  [indicatie, tatu, fors, mammaabces, link, vraa...
# 20  [st, ablatio, rechts, ivm, mammacarcinoom, pat...
# 21  [follow, up, ablatio, rechts, mammografie, lin...
# 28  [controle, ablatio, link, verslag, mammografie...
# 29  [geabcedeerde, cyste, l, mamma, mgr, ter, uits...
# 30  [indicatie, follow, up, familiaire, belasting,...
# 31  [vervolgen, familiaire, belasting, mastopathie...
# 33  [indicatie, juli, cyste, rechts, advies, via, ...
# 36  [jaarlijkse, screening, verband, familiaire, b...
# 37  [vervolgen, status, mammacarcinoom, rechts, wa...
# 38  [controle, sparende, therapie, rechts, verslag...
# 39  [status, sparende, therapie, rechts, vervolgen...
# 40  [mca, verslag, mammografie, rechts, standaardp...
# 41  [genetisch, advies, ter, controle, bekend, cys...
# 42  [belaste, familie, anamnese, vor, mammacarcino...
# 43  [klinische, follow, up, status, mamma, ca, lin...
# 44  [klinische, follow, up, status, mamma, ca, lin...
# 45  [status, dci, re, waarvoor, ablatio, verslag, ...
# 46  [follow, up, status, mammaca, rechts, waarvoor...
# 47  [follow, up, status, mammaca, rechts, verslag,...
# 49  [controle, verband, radiotherapie, morbus, hod...
# 51  [jaarlijkse, mammografie, x, mammografie, beid...
# 52  [st, grm, re, aanw, maligniteit, li, mamma, ve...
# 54  [indicatie, fu, patiente, dement, verslag, t, ...
# 56  [indicatie, jaarlijkse, controle, verslag, bli...
# 57  [juli, microcalc, atypische, ductaal, hyperpla...
# 58  [familiair, belast, ene, jaar, svob, jaar, con...
# 60  [follow, up, status, mammasparende, therapie, ...
# 63  [klinische, belaste, familieanamnese, mammogra...
# 64  [vervolgen, status, sparende, therapie, rechts...
# 66  [tien, jaar, grm, link, verslag, ter, vergelij...
# 67  [status, mst, link, verslag, ter, vergelijking...
# 68  [status, mammacarcinoom, rechts, waarvoor, mst...
# 69  [status, mst, link, follow, up, ½, jaar, versl...
# 70  [klinische, routineonderzoek, status, verwijde...
# 71  [indicatie, follow, up, ivm, apocriene, metapl...
# 72  [jaarlijkse, controle, x, mammografie, beiderz...
# 73  [mammacarcinoom, link, waarvoor, lumpectomie, ...
# 74  [controle, mammografie, doorgemaakt, mammaca, ...
# 75  [mammacarcinoom, rechts, verslag, mammografie,...
# 76  [patient, geen, aanvraagbriefje, status, mamma...

# %%
df_main_data = df_training[['cleaned_text','BIRADS']]

# %%
>>> from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features=1500, min_df=0.05, max_df=0.7, stop_words=stop, ngram_range =(1,3))
X = vectorizer.fit_transform(df_main_data.cleaned_text)
y = df_main_data.BIRADS
y = y.astype('int')

# %%
df_main_data.cleaned_text.iloc[2]
# Out:
# 'controle mammografie x mammografie rechts vergelijkend onderzoek onveranderd beeld beeld scleroserende fibroadenosis suggestieve schaduw centraal laterale gedeelte rechtermamma craniocaudale opname detailopname reproduceerbaar beeld passend summatie geen aanwijzingen maligniteit axillair geen vergrote lymfeklieren'

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
import sklearn.metrics as metrics
clf = DecisionTreeClassifier(class_weight = 'balanced')
clf_FS = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
f1 = f1_score(y_test, y_pred,average = 'macro')
print("F1 Score",f1)
# Out:
# Accuracy: 0.6341231325530498
# F1 Score 0.355383403738251

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import balanced_accuracy_score
print(classification_report(y_test,y_pred))
print(balanced_accuracy_score(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.07      0.08      0.07       132
#            1       0.62      0.63      0.63      2989
#            2       0.76      0.73      0.75      5821
#            3       0.20      0.22      0.21       503
#            4       0.39      0.43      0.41       679
#            5       0.34      0.31      0.32       298
#            6       0.08      0.13      0.10        87
#
#     accuracy                           0.63     10509
#    macro avg       0.35      0.36      0.36     10509
# weighted avg       0.64      0.63      0.64     10509
#
# 0.3617294945212925

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[  11   24   59   12   19    0    7]
#  [  38 1889  839   71  102   31   19]
#  [  78  958 4257  252  185   33   58]
#  [  18   55  216  111   65   26   12]
#  [  10   68  143   68  294   79   17]
#  [   4   32   45   30   84   91   12]
#  [   3   18   31    6   12    6   11]]
#               precision    recall  f1-score   support
#
#            0       0.07      0.08      0.07       132
#            1       0.62      0.63      0.63      2989
#            2       0.76      0.73      0.75      5821
#            3       0.20      0.22      0.21       503
#            4       0.39      0.43      0.41       679
#            5       0.34      0.31      0.32       298
#            6       0.08      0.13      0.10        87
#
#     accuracy                           0.63     10509
#    macro avg       0.35      0.36      0.36     10509
# weighted avg       0.64      0.63      0.64     10509
#
# 0.6341231325530498

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
import sklearn.metrics as metrics
clf_test = DecisionTreeClassifier()
clf_FS_test = clf_test.fit(X_train,y_train)
y_pred = clf_test.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
f1 = f1_score(y_test, y_pred,average = 'macro')
print("F1 Score",f1)
# Out:
# Accuracy: 0.6365020458654487
# F1 Score 0.3435292451427447

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import balanced_accuracy_score
print(classification_report(y_test,y_pred))
print(balanced_accuracy_score(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.06      0.05      0.06       132
#            1       0.62      0.64      0.63      2989
#            2       0.76      0.74      0.75      5821
#            3       0.21      0.21      0.21       503
#            4       0.38      0.38      0.38       679
#            5       0.30      0.31      0.31       298
#            6       0.07      0.08      0.07        87
#
#     accuracy                           0.64     10509
#    macro avg       0.34      0.35      0.34     10509
# weighted avg       0.64      0.64      0.64     10509
#
# 0.3455167545209655

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[   7   26   67    6   12    6    8]
#  [  31 1906  860   57   85   36   14]
#  [  51  961 4309  249  154   43   54]
#  [  11   61  216  106   73   35    1]
#  [  10   93  158   53  261   89   15]
#  [   1   36   51   28   82   93    7]
#  [   0   16   30   13   17    4    7]]
#               precision    recall  f1-score   support
#
#            0       0.06      0.05      0.06       132
#            1       0.62      0.64      0.63      2989
#            2       0.76      0.74      0.75      5821
#            3       0.21      0.21      0.21       503
#            4       0.38      0.38      0.38       679
#            5       0.30      0.31      0.31       298
#            6       0.07      0.08      0.07        87
#
#     accuracy                           0.64     10509
#    macro avg       0.34      0.35      0.34     10509
# weighted avg       0.64      0.64      0.64     10509
#
# 0.6365020458654487

# %%
from sklearn import svm
from eli5.sklearn import PermutationImportance
clf_1 = svm.SVC(class_weight = 'balanced')
svc = clf_1.fit(X_train, y_train)
y_pred_svm = clf_1.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_svm))
print("balanced accuracy:",balanced_accuracy_score(y_test,y_pred_svm))
f1 = f1_score(y_test, y_pred_svm,average = 'macro')
print("F1 Score:",f1)
# Out:
# Accuracy: 0.7169093158245313
# balanced accuracy: 0.5507246137497762
# F1 Score: 0.5171557217050616

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(class_weight='balanced')
logForFS =logreg.fit(X_train,y_train)
y_pred_LR=logreg.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_LR))
print("balanced accuracy:",balanced_accuracy_score(y_test,y_pred_LR))
f1 = f1_score(y_test, y_pred_LR,average = 'macro')
print("F1 Score:",f1)
# Out:
# Accuracy: 0.6020553811019127
# balanced accuracy: 0.5715137207126872
# F1 Score: 0.4274501944661385
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import eli5
from eli5.sklearn import PermutationImportance
from sklearn.svm import SVC

# %%
pip install eli5
# Out:
# Requirement already satisfied: eli5 in /opt/anaconda3/lib/python3.8/site-packages (0.11.0)
# Requirement already satisfied: attrs>16.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from eli5) (20.3.0)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/anaconda3/lib/python3.8/site-packages (from eli5) (0.8.9)
# Requirement already satisfied: numpy>=1.9.0 in /opt/anaconda3/lib/python3.8/site-packages (from eli5) (1.19.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.8/site-packages (from eli5) (2.11.2)
# Requirement already satisfied: scikit-learn>=0.20 in /opt/anaconda3/lib/python3.8/site-packages (from eli5) (0.23.2)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.8/site-packages (from eli5) (1.5.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from eli5) (1.15.0)
# Requirement already satisfied: graphviz in /opt/anaconda3/lib/python3.8/site-packages (from eli5) (0.16)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.8/site-packages (from jinja2->eli5) (1.1.1)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20->eli5) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20->eli5) (2.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
eli5.show_weights(estimator=logForFS, 
                  feature_names= list(vectorizer.get_feature_names()),
                 top=(10, 5))
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=0
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=2
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=3
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=4
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=5
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=6
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.669
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         echografisch
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.24%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.697
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         geen pathologische microcalcificaties
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.656
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         belasting
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.343
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         weefsel
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.11%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.451
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         focale
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.287
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         architectuurverstoringen
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.66%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.224
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         birads
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.13%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.034
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mammogram
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.32%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.960
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         borst
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.918
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         opname
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 89.43%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 155 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.15%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 144 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.856
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         axillair
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.98%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -4.366
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mammogram acr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.27%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -4.686
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         patiënt
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 84.94%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -4.834
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         palpabele afwijking
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -7.251
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em;

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (4.6.1)
# Requirement already satisfied: packaging in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from transformers) (20.4)
# Requirement already satisfied: regex!=2019.12.17 in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from transformers) (2020.6.8)
# Requirement already satisfied: huggingface-hub==0.0.8 in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from transformers) (0.0.8)
# Requirement already satisfied: requests in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from transformers) (2.24.0)
# Requirement already satisfied: numpy>=1.17 in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from transformers) (1.19.4)
# Requirement already satisfied: filelock in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from transformers) (4.47.0)
# Requirement already satisfied: sacremoses in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from transformers) (0.0.45)
# Collecting tokenizers<0.11,>=0.10.1
#   Using cached tokenizers-0.10.3-cp38-cp38-macosx_10_11_x86_64.whl (2.2 MB)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: six in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from packaging->transformers) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: joblib in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from sacremoses->transformers) (0.16.0)
# Requirement already satisfied: click in /Users/deepureddy/opt/anaconda3/lib/python3.8/site-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: tokenizers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.9.3
#     Uninstalling tokenizers-0.9.3:
#       Successfully uninstalled tokenizers-0.9.3
# Successfully installed tokenizers-0.10.3

# %%
! pip list | grep "tensorflow"   # Check tensorflow==2.0.0, tensorflow-gpu==2.0.0
! pip list | grep "transformers" # Check transformers>=2.0.0
# Out:
# transformers                       4.6.1

# %%
df_main_data.to_csv("output_filename.csv", index=False, encoding='utf8')

# %%
pip install torch==1.4.0
# Out:
# Requirement already satisfied: torch==1.4.0 in /opt/anaconda3/lib/python3.8/site-packages (1.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install transformers -U
# Out:
# Requirement already up-to-date: transformers in /opt/anaconda3/lib/python3.8/site-packages (4.6.1)
# Requirement already satisfied, skipping upgrade: filelock in /opt/anaconda3/lib/python3.8/site-packages (from transformers) (3.0.12)
# Requirement already satisfied, skipping upgrade: huggingface-hub==0.0.8 in /opt/anaconda3/lib/python3.8/site-packages (from transformers) (0.0.8)
# Requirement already satisfied, skipping upgrade: packaging in /opt/anaconda3/lib/python3.8/site-packages (from transformers) (20.4)
# Requirement already satisfied, skipping upgrade: sacremoses in /opt/anaconda3/lib/python3.8/site-packages (from transformers) (0.0.45)
# Requirement already satisfied, skipping upgrade: numpy>=1.17 in /opt/anaconda3/lib/python3.8/site-packages (from transformers) (1.19.2)
# Requirement already satisfied, skipping upgrade: regex!=2019.12.17 in /opt/anaconda3/lib/python3.8/site-packages (from transformers) (2020.10.15)
# Requirement already satisfied, skipping upgrade: requests in /opt/anaconda3/lib/python3.8/site-packages (from transformers) (2.24.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Using cached tokenizers-0.10.3-cp38-cp38-macosx_10_11_x86_64.whl (2.2 MB)
# Requirement already satisfied, skipping upgrade: tqdm>=4.27 in /opt/anaconda3/lib/python3.8/site-packages (from transformers) (4.50.2)
# Requirement already satisfied, skipping upgrade: six in /opt/anaconda3/lib/python3.8/site-packages (from packaging->transformers) (1.15.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied, skipping upgrade: joblib in /opt/anaconda3/lib/python3.8/site-packages (from sacremoses->transformers) (0.17.0)
# Requirement already satisfied, skipping upgrade: click in /opt/anaconda3/lib/python3.8/site-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2020.6.20)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (3.0.4)
# Installing collected packages: tokenizers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.9.3
#     Uninstalling tokenizers-0.9.3:
#       Successfully uninstalled tokenizers-0.9.3
# Successfully installed tokenizers-0.10.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from transformers import BertTokenizerFast,AutoModel

# specify GPU
device = torch.device("cuda")

# %%
df_main_data
# Out:
#                                             cleaned_text BIRADS
# 1      controle mammografie afwijkingen verslag verge...      2
# 2      klinische followup kadermammacarcinoom rechts ...      2
# 3      controle mammografie x mammografie rechts verg...      2
# 4      mammacarcinoom rechts follow up verslag ter ve...      1
# 6      indicatie fu kader belaste fa verslag t o v ap...      1
# ...                                                  ...    ...
# 54395  klinische jarige vrouw hengelo komt via bevolk...      4
# 54397  klinische jarige vrouw hengelo voelt sinds aan...      1
# 54398  klinische jarige vrouw borne voelt sinds maand...      2
# 54400  klinische jarige vrouw almelo pijn r borst sin...      2
# 54401  klinische jarige vrouw bentelo voelt knobbeltj...      2
#
# [35030 rows x 2 columns]

# %%
train_text, temp_text, train_labels, temp_labels = train_test_split(df_main_data['cleaned_text'], df_main_data['BIRADS'], 
                                                                    random_state=2018, 
                                                                    test_size=0.3, 
                                                                    stratify=df_main_data['BIRADS'])

# %%
val_text, test_text, val_labels, test_labels = train_test_split(temp_text, temp_labels, 
                                                                random_state=2018, 
                                                                test_size=0.5, 
                                                                stratify=temp_labels)

# %%
bert = AutoModel.from_pretrained('bert-base-uncased')

# %%
seq_len = [len(i.split()) for i in train_text]

pd.Series(seq_len).hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
pip install tokenizer
# Out:
# Requirement already satisfied: tokenizer in /opt/anaconda3/lib/python3.8/site-packages (3.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in /opt/anaconda3/lib/python3.8/site-packages (2.4.3)
# Requirement already satisfied: h5py in /opt/anaconda3/lib/python3.8/site-packages (from keras) (3.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/anaconda3/lib/python3.8/site-packages (from keras) (1.19.2)
# Requirement already satisfied: scipy>=0.14 in /opt/anaconda3/lib/python3.8/site-packages (from keras) (1.5.2)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.8/site-packages (from keras) (5.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /opt/anaconda3/lib/python3.8/site-packages (2.5.0)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.17.1)
# Requirement already satisfied: google-pasta~=0.2 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: wrapt~=1.12.1 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: wheel~=0.35 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.35.1)
# Requirement already satisfied: tensorboard~=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: six~=1.15.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: termcolor~=1.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: astunparse~=1.6.3 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: h5py~=3.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.5.0.dev2021032900)
# Requirement already satisfied: grpcio~=1.34.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.34.1)
# Requirement already satisfied: opt-einsum~=3.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: numpy~=1.19.2 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.19.2)
# Requirement already satisfied: absl-py~=0.10 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.12.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: gast==0.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow) (1.30.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow) (2.24.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow) (50.3.1.post20201107)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (0.2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2.10)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/anaconda3/lib/python3.8/site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import BertTokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
tokens_train = tokenizer.batch_encode_plus(
    train_text.tolist(),
    max_length = None,
    pad_to_max_length=True,
    truncation=True
)

# tokenize and encode sequences in the validation set
tokens_val = tokenizer.batch_encode_plus(
    val_text.tolist(),
    max_length = None,
    pad_to_max_length=True,
    truncation=True
)

# tokenize and encode sequences in the test set
tokens_test = tokenizer.batch_encode_plus(
    test_text.tolist(),
    max_length = None,
    pad_to_max_length=True,
    truncation=True
)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/transformers/tokenization_utils_base.py:2016: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
train_seq = torch.tensor(tokens_train['input_ids'])
train_mask = torch.tensor(tokens_train['attention_mask'])
train_y = torch.tensor(train_labels.tolist())

val_seq = torch.tensor(tokens_val['input_ids'])
val_mask = torch.tensor(tokens_val['attention_mask'])
val_y = torch.tensor(val_labels.tolist())

test_seq = torch.tensor(tokens_test['input_ids'])
test_mask = torch.tensor(tokens_test['attention_mask'])
test_y = torch.tensor(test_labels.tolist())

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

#define a batch size
batch_size = 50

# wrap tensors
train_data = TensorDataset(train_seq, train_mask, train_y)

# sampler for sampling the data during training
train_sampler = RandomSampler(train_data)

# dataLoader for train set
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

# wrap tensors
val_data = TensorDataset(val_seq, val_mask, val_y)

# sampler for sampling the data during training
val_sampler = SequentialSampler(val_data)

# dataLoader for validation set
val_dataloader = DataLoader(val_data, sampler = val_sampler, batch_size=batch_size)

# %%
from sklearn.utils.class_weight import compute_class_weight

#compute the class weights
class_weights = compute_class_weight('balanced', np.unique(train_labels), train_labels)

print("Class Weights:",class_weights)
# Out:
# Class Weights: [11.67666667  0.49289433  0.26116454  2.8619281   2.20730939  5.30757576
#  15.23043478]
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:67: FutureWarning: Pass classes=[0 1 2 3 4 5 6], y=9323     2
# 53254    3
# 2411     1
# 14750    2
# 21573    2
#         ..
# 17249    1
# 41963    2
# 50741    2
# 3615     4
# 47246    2
# Name: BIRADS, Length: 24521, dtype: object as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %%
conda install pytorch torchvision cudatoolkit=10.2 -c pytorch
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - cudatoolkit=10.2
#
# Current channels:
#
#   - https://conda.anaconda.org/pytorch/osx-64
#   - https://conda.anaconda.org/pytorch/noarch
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
def train():
  
  model.train()

  total_loss, total_accuracy = 0, 0
  
  # empty list to save model predictions
  total_preds=[]
  
  # iterate over batches
  for step,batch in enumerate(train_dataloader):
    
    # progress update after every 50 batches.
    if step % 50 == 0 and not step == 0:
      print('  Batch {:>5,}  of  {:>5,}.'.format(step, len(train_dataloader)))

    # push the batch to gpu
    batch = [r.to(device) for r in batch]
 
    sent_id, mask, labels = batch

    # clear previously calculated gradients 
    model.zero_grad()        

    # get model predictions for the current batch
    preds = model(sent_id, mask)

    # compute the loss between actual and predicted values
    loss = cross_entropy(preds, labels)

    # add on to the total loss
    total_loss = total_loss + loss.item()

    # backward pass to calculate the gradients
    loss.backward()

    # clip the the gradients to 1.0. It helps in preventing the exploding gradient problem
    torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

    # update parameters
    optimizer.step()

    # model predictions are stored on GPU. So, push it to CPU
    preds=preds.detach().cpu().numpy()

    # append the model predictions
    total_preds.append(preds)

  # compute the training loss of the epoch
  avg_loss = total_loss / len(train_dataloader)
  
  # predictions are in the form of (no. of batches, size of batch, no. of classes).
  # reshape the predictions in form of (number of samples, no. of classes)
  total_preds  = np.concatenate(total_preds, axis=0)

  #returns the loss and predictions
  return avg_loss, total_preds

# %%
def evaluate():
  
  print("\nEvaluating...")
  
  # deactivate dropout layers
  model.eval()

  total_loss, total_accuracy = 0, 0
  
  # empty list to save the model predictions
  total_preds = []

  # iterate over batches
  for step,batch in enumerate(val_dataloader):
    
    # Progress update every 50 batches.
    if step % 50 == 0 and not step == 0:
      
      # Calculate elapsed time in minutes.
      elapsed = format_time(time.time() - t0)
            
      # Report progress.
      print('  Batch {:>5,}  of  {:>5,}.'.format(step, len(val_dataloader)))

    # push the batch to gpu
    batch = [t.to(device) for t in batch]

    sent_id, mask, labels = batch

    # deactivate autograd
    with torch.no_grad():
      
      # model predictions
      preds = model(sent_id, mask)

      # compute the validation loss between actual and predicted values
      loss = cross_entropy(preds,labels)

      total_loss = total_loss + loss.item()

      preds = preds.detach().cpu().numpy()

      total_preds.append(preds)

  # compute the validation loss of the epoch
  avg_loss = total_loss / len(val_dataloader) 

  # reshape the predictions in form of (number of samples, no. of classes)
  total_preds  = np.concatenate(total_preds, axis=0)

  return avg_loss, total_preds

# %%
path = 'saved_weights.pt'
model.load_state_dict(torch.load(path))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-f14ee0750792> in <module>
#       1 path = 'saved_weights.pt'
# ----> 2 model.load_state_dict(torch.load(path))
#
# NameError: name 'model' is not defined

# %%
pip install torchvision==0.4.0 -f https://download.pytorch.org/whl/torch_stable.html

# %%
from simpletransformers.model import TransformerModel
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-2e741a2fd174> in <module>
# ----> 1 from simpletransformers.model import TransformerModel
#
# /opt/anaconda3/lib/python3.8/site-packages/simpletransformers/model.py in <module>
# ----> 1 from simpletransformers.classification.classification_model import ClassificationModel
#       2
#       3 TransformerModel = ClassificationModel
#
# /opt/anaconda3/lib/python3.8/site-packages/simpletransformers/classification/__init__.py in <module>
# ----> 1 from simpletransformers.classification.classification_model import ClassificationModel
#       2 from simpletransformers.classification.multi_label_classification_model import (
#       3     MultiLabelClassificationModel,
#       4 )
#       5 from simpletransformers.classification.multi_modal_classification_model import (
#
# /opt/anaconda3/lib/python3.8/site-packages/simpletransformers/classification/classification_model.py in <module>
#      91 from transformers.convert_graph_to_onnx import convert, quantize
#      92
# ---> 93 from simpletransformers.classification.classification_utils import (
#      94     InputExample,
#      95     LazyClassificationDataset,
#
# /opt/anaconda3/lib/python3.8/site-packages/simpletransformers/classification/classification_utils.py in <module>
#      38
#      39 try:
# ---> 40     import torchvision
#      41     import torchvision.transforms as transforms
#      42
#
# /opt/anaconda3/lib/python3.8/site-packages/torchvision/__init__.py in <module>
#       4 from .extension import _HAS_OPS
#       5
# ----> 6 from torchvision import models
#       7 from torchvision import datasets
#       8 from torchvision import ops
#
# /opt/anaconda3/lib/python3.8/site-packages/torchvision/models/__init__.py in <module>
#      10 from .shufflenetv2 import *
#      11 from . import segmentation
# ---> 12 from . import detection
#      13 from . import video
#      14 from . import quantization
#
# /opt/anaconda3/lib/python3.8/site-packages/torchvision/models/detection/__init__.py in <module>
# ----> 1 from .faster_rcnn import *
#       2 from .mask_rcnn import *
#       3 from .keypoint_rcnn import *
#       4 from .retinanet import *
#
# /opt/anaconda3/lib/python3.8/site-packages/torchvision/models/detection/faster_rcnn.py in <module>
#       3 import torch.nn.functional as F
#       4
# ----> 5 from torchvision.ops import MultiScaleRoIAlign
#       6
#       7 from ._utils import overwrite_eps
#
# /opt/anaconda3/lib/python3.8/site-packages/torchvision/ops/__init__.py in <module>
# ----> 1 from .boxes import nms, batched_nms, remove_small_boxes, clip_boxes_to_image, box_area, box_iou, generalized_box_iou
#       2 from .boxes import box_convert
#       3 from .deform_conv import deform_conv2d, DeformConv2d
#       4 from .roi_align import roi_align, RoIAlign
#       5 from .roi_pool import roi_pool, RoIPool
#
# /opt/anaconda3/lib/python3.8/site-packages/torchvision/ops/boxes.py in <module>
#      37
#      38
# ---> 39 @torch.jit._script_if_tracing
#      40 def batched_nms(
#      41     boxes: Tensor,
#
# AttributeError: module 'torch.jit' has no attribute '_script_if_tracing'
